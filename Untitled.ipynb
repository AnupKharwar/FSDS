# %%
import pandas as pd
import sklearn

# %%
df = pd.read_json('Auth_test_file.txt', orient='records')

# df = pd.read_csv('Install Packages Cmd.txt')

# %%
df
# Out:
#        Auth.AuthID      Source Requesting Provider NPI Servicing Provider NPI  \
# 0           570053  Web Portal              1104801349             1255390290
# 1           570061  Web Portal              1952366106             1689699175
# 2           570062  Web Portal              1487649430             1245523463
# 3           570063  Web Portal              1104801349             1710409214
# 4           570069  Web Portal              1588659528             1225393432
# ...            ...         ...                     ...                    ...
# 26354       600537  Web Portal              1588659528             1255561551
# 26355       600543   Telephone              1093219818             1093219818
# 26356       600544  Web Portal              1588659528             1366447203
# 26357       600546  Web Portal              1487649430             1437567260
# 26358       600550  Web Portal              1174559603             1174559603
#
# ...

# %%
df = pd.read_json('prediction.txt',orient='records')

# %%
df
# Out:
#    id Prediction  Val
# 0   1   Approved  88%
# 1   2     Denied  22%
# 2   3   Approved  36%
# 3   4   Approved  45%
# 4   5     Denied  98%

# %%
out = df.to_json(orient='records')
with open('output.txt', 'w') as f:
    f.write(out)
